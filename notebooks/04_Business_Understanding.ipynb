# %% [markdown]
# # Airbnb Pricing & Market Intelligence
#
# ## Business Understanding

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

dim_listing = pd.read_csv("../data/processed/dim_listing.csv")
dim_host = pd.read_csv("../data/processed/dim_host.csv")
fact_reviews = pd.read_csv("../data/processed/fact_reviews.csv")

print("Tables Loaded Successfully")
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_21332\1748450822.py:7: DtypeWarning: Columns (0: host_response_time) have mixed types. Specify dtype option on import or set low_memory=False.
#   dim_host = pd.read_csv("../data/processed/dim_host.csv")
# Tables Loaded Successfully

# %%
print("Listings :", len(dim_listing))
print("Hosts    :", len(dim_host))
print("Reviews  :", len(fact_reviews))
# Out:
# Listings : 279434
# Hosts    : 181805
# Reviews  : 5372983

# %% [markdown]
# ## Business Objectives
#
# - Compare Airbnb market characteristics across major global cities.
# - Identify the key attributes that influence listing prices.
# - Analyze pricing differences across room types, property types, and locations.
# - Study customer review activity and identify trends over time.
# - Detect seasonality patterns in Airbnb review behavior.
# - Evaluate host characteristics and their relationship with pricing and ratings.
# - Assess customer satisfaction across cities and discuss value-for-travel limitations due to multi-currency pricing.
# - Develop actionable market intelligence insights for hosts and travelers.

# %% [markdown]
# ## Analytical Questions
#
# - Can major differences be identified between Airbnb markets across cities?
# - How does listing supply differ across cities?
# - Which neighbourhoods command premium pricing within each city?
# - Which listing attributes have the strongest influence on price?
# - How do room types and property types impact pricing?
# - How does accommodation capacity relate to pricing?
# - Do superhosts achieve better ratings or pricing performance?
# - Are there observable trends in review activity over time?
# - Are there seasonal patterns in customer reviews?
# - What limitations exist when comparing value-for-travel across cities in a multi-currency dataset?
